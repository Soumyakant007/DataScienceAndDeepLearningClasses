# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
btc_df=pd.read_csv("./crypto_data/bitcoin_price.csv")
eth_df=pd.read_csv("./crypto_data/ethereum_price.csv")
lte_df=pd.read_csv("./crypto_data/litecoin_price.csv")
mno_df=pd.read_csv("./crypto_data/monero_price.csv")
neo_df=pd.read_csv("./crypto_data/neo_price.csv")
qtum_df=pd.read_csv("./crypto_data/qtum_price.csv")
rpp_df=pd.read_csv("./crypto_data/ripple_price.csv")

# %%
btc_df.describe()
# Out:
#               Open         High          Low        Close
# count  1655.000000  1655.000000  1655.000000  1655.000000
# mean    822.136127   845.812665   800.640906   826.285541
# std    1108.245793  1147.157863  1077.408893  1119.053510
# min      68.500000    74.560000    65.530000    68.430000
# 25%     263.850000   270.070000   260.030000   264.135000
# 50%     453.380000   458.200000   444.960000   453.380000
# 75%     743.485000   759.425000   731.785000   744.820000
# max    7404.520000  7617.480000  7333.190000  7407.410000

# %%
btc_df.head()
# Out:
#        Date     Open     High      Low    Close          Volume  \
# 0  7-Nov-17  7023.10  7253.32  7023.10  7144.38  2,32,63,40,000
# 1  6-Nov-17  7403.22  7445.77  7007.31  7022.76  3,11,19,00,000
# 2  5-Nov-17  7404.52  7617.48  7333.19  7407.41  2,38,04,10,000
# 3  4-Nov-17  7164.48  7492.86  7031.28  7379.95  2,48,38,00,000
# 4  3-Nov-17  7087.53  7461.29  7002.94  7207.76  3,36,98,60,000
#
#           Market Cap
# 0  1,17,05,60,00,000
# 1  1,23,37,90,00,000
# 2  1,23,38,80,00,000
# 3  1,19,37,60,00,000
# 4  1,18,08,40,00,000

# %%
btc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1655 entries, 0 to 1654
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        1655 non-null   object
#  1   Open        1655 non-null   float64
#  2   High        1655 non-null   float64
#  3   Low         1655 non-null   float64
#  4   Close       1655 non-null   float64
#  5   Volume      1655 non-null   object
#  6   Market Cap  1655 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 90.6+ KB

# %%
btc_df.shape
# Out:
# (1655, 7)

# %%
eth_df.shape
# Out:
# (824, 7)

# %%
lte_df.shape
# Out:
# (1655, 7)

# %%
mno_df.shape
# Out:
# (1266, 7)

# %%
neo_df.shape
# Out:
# (425, 7)

# %%
print(btc_df["Date"])
# Out:
# 0        7-Nov-17
# 1        6-Nov-17
# 2        5-Nov-17
# 3        4-Nov-17
# 4        3-Nov-17
#           ...
# 1650     2-May-13
# 1651     1-May-13
# 1652    30-Apr-13
# 1653    29-Apr-13
# 1654    28-Apr-13
# Name: Date, Length: 1655, dtype: object

# %%
btc_df["Date"]=pd.to_datetime(btc_df["Date"])
eth_df["Date"]=pd.to_datetime(eth_df["Date"])
lte_df["Date"]=pd.to_datetime(lte_df["Date"])
mno_df["Date"]=pd.to_datetime(mno_df["Date"])
neo_df["Date"]=pd.to_datetime(neo_df["Date"])
qtum_df["Date"]=pd.to_datetime(qtum_df["Date"])
rpp_df["Date"]=pd.to_datetime(rpp_df["Date"])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2068\3667290456.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   btc_df["Date"]=pd.to_datetime(btc_df["Date"])
# C:\Users\HP\AppData\Local\Temp\ipykernel_2068\3667290456.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   eth_df["Date"]=pd.to_datetime(eth_df["Date"])
# C:\Users\HP\AppData\Local\Temp\ipykernel_2068\3667290456.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   lte_df["Date"]=pd.to_datetime(lte_df["Date"])
# ...

# %%
btc_df['Market Cap'] = pd.to_numeric(btc_df['Market Cap'].str.replace(',', ''), errors='coerce')
btc_df['Volume'] = pd.to_numeric(btc_df['Volume'].str.replace(',', ''), errors='coerce')

eth_df['Market Cap'] = pd.to_numeric(eth_df['Market Cap'].str.replace(',', ''), errors='coerce')
eth_df['Volume'] = pd.to_numeric(eth_df['Volume'].str.replace(',', ''), errors='coerce')

lte_df['Market Cap'] = pd.to_numeric(lte_df['Market Cap'].str.replace(',', ''), errors='coerce')
lte_df['Volume'] = pd.to_numeric(lte_df['Volume'].str.replace(',', ''), errors='coerce')

mno_df['Market Cap'] = pd.to_numeric(mno_df['Market Cap'].str.replace(',', ''), errors='coerce')
mno_df['Volume'] = pd.to_numeric(mno_df['Volume'].str.replace(',', ''), errors='coerce')

neo_df['Market Cap'] = pd.to_numeric(neo_df['Market Cap'].str.replace(',', ''), errors='coerce')
neo_df['Volume'] = pd.to_numeric(neo_df['Volume'].str.replace(',', ''), errors='coerce')

qtum_df['Market Cap'] = pd.to_numeric(qtum_df['Market Cap'].str.replace(',', ''), errors='coerce')
qtum_df['Volume'] = pd.to_numeric(qtum_df['Volume'].str.replace(',', ''), errors='coerce')

rpp_df['Market Cap'] = pd.to_numeric(rpp_df['Market Cap'].str.replace(',', ''), errors='coerce')
rpp_df['Volume'] = pd.to_numeric(rpp_df['Volume'].str.replace(',', ''), errors='coerce')

# %%
btc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1655 entries, 0 to 1654
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        1655 non-null   datetime64[ns]
#  1   Open        1655 non-null   float64
#  2   High        1655 non-null   float64
#  3   Low         1655 non-null   float64
#  4   Close       1655 non-null   float64
#  5   Volume      1412 non-null   float64
#  6   Market Cap  1655 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 90.6 KB

# %%
"""time_df_btc_high=btc_df[['Date', 'High']]
time_df_eth_high=eth_df[['Date', 'High']]
time_df_lte_high=lte_df[['Date', 'High']]
time_df_mno_high=mno_df[['Date', 'High']]
time_df_neo_high=neo_df[['Date', 'High']]
time_df_qtum_high=qtum_df[['Date', 'High']]
time_df_rpp_high=rpp_df[['Date', 'High']]"""
# Out:
# "time_df_btc_high=btc_df[['Date', 'High']]\ntime_df_eth_high=eth_df[['Date', 'High']]\ntime_df_lte_high=lte_df[['Date', 'High']]\ntime_df_mno_high=mno_df[['Date', 'High']]\ntime_df_neo_high=neo_df[['Date', 'High']]\ntime_df_qtum_high=qtum_df[['Date', 'High']]\ntime_df_rpp_high=rpp_df[['Date', 'High']]"

# %%
time_df_btc_high = btc_df.set_index('Date')['High']
time_df_eth_high = eth_df.set_index('Date')['High']
time_df_lte_high = lte_df.set_index('Date')['High']
time_df_mno_high = mno_df.set_index('Date')['High']
time_df_neo_high = neo_df.set_index('Date')['High']
time_df_qtum_high = qtum_df.set_index('Date')['High']
time_df_rpp_high = rpp_df.set_index('Date')['High']

# %%
"""type(time_df_btc)"""
# Out:
# 'type(time_df_btc)'

# %%
"""time_df_btc_high.set_index("Date",inplace=True)
time_df_eth_high.set_index("Date",inplace=True)
time_df_lte_high.set_index("Date",inplace=True)
time_df_mno_high.set_index("Date",inplace=True)
time_df_neo_high.set_index("Date",inplace=True)
time_df_qtum_high.set_index("Date",inplace=True)
time_df_rpp_high.set_index("Date",inplace=True)"""
# Out:
# 'time_df_btc_high.set_index("Date",inplace=True)\ntime_df_eth_high.set_index("Date",inplace=True)\ntime_df_lte_high.set_index("Date",inplace=True)\ntime_df_mno_high.set_index("Date",inplace=True)\ntime_df_neo_high.set_index("Date",inplace=True)\ntime_df_qtum_high.set_index("Date",inplace=True)\ntime_df_rpp_high.set_index("Date",inplace=True)'

# %%
plt.figure(figsize=(20,8))
custom = sns.color_palette("husl", 7)
sns.lineplot(data=time_df_btc_high,palette=[custom[0]],label="BTC")
sns.lineplot(data=time_df_eth_high,palette=[custom[1]],label="ETH")
sns.lineplot(data=time_df_lte_high,palette=[custom[2]],label="LTC")
sns.lineplot(data=time_df_mno_high,palette=[custom[3]],label="MNO")
sns.lineplot(data=time_df_neo_high,palette=[custom[4]],label="NEO")
sns.lineplot(data=time_df_qtum_high,palette=[custom[5]],label="QTUM")
sns.lineplot(data=time_df_rpp_high,palette=[custom[6]],label="RPP")
plt.xlabel("Date")
plt.ylabel("High")
plt.yscale("log")
plt.grid(True)
plt.legend()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2068\781013613.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=time_df_btc_high,palette=[custom[0]],label="BTC")
# C:\Users\HP\AppData\Local\Temp\ipykernel_2068\781013613.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=time_df_eth_high,palette=[custom[1]],label="ETH")
# C:\Users\HP\AppData\Local\Temp\ipykernel_2068\781013613.py:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=time_df_lte_high,palette=[custom[2]],label="LTC")
# C:\Users\HP\AppData\Local\Temp\ipykernel_2068\781013613.py:6: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=time_df_mno_high,palette=[custom[3]],label="MNO")
# C:\Users\HP\AppData\Local\Temp\ipykernel_2068\781013613.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
# ...

# %%
"""time_df_btc_mc=btc_df[['Date', 'Market Cap']]
time_df_eth_mc=eth_df[['Date', 'Market Cap']]
time_df_lte_mc=lte_df[['Date', 'Market Cap']]
time_df_mno_mc=mno_df[['Date', 'Market Cap']]
time_df_neo_mc=neo_df[['Date', 'Market Cap']]
time_df_qtum_mc=qtum_df[['Date', 'Market Cap']]
time_df_rpp_mc=rpp_df[['Date', 'Market Cap']]

time_df_btc_mc.set_index("Date",inplace=True)
time_df_eth_mc.set_index("Date",inplace=True)
time_df_lte_mc.set_index("Date",inplace=True)
time_df_mno_mc.set_index("Date",inplace=True)
time_df_neo_mc.set_index("Date",inplace=True)
time_df_qtum_mc.set_index("Date",inplace=True)
time_df_rpp_mc.set_index("Date",inplace=True)

"""
# Out:
# 'time_df_btc_mc=btc_df[[\'Date\', \'Market Cap\']]\ntime_df_eth_mc=eth_df[[\'Date\', \'Market Cap\']]\ntime_df_lte_mc=lte_df[[\'Date\', \'Market Cap\']]\ntime_df_mno_mc=mno_df[[\'Date\', \'Market Cap\']]\ntime_df_neo_mc=neo_df[[\'Date\', \'Market Cap\']]\ntime_df_qtum_mc=qtum_df[[\'Date\', \'Market Cap\']]\ntime_df_rpp_mc=rpp_df[[\'Date\', \'Market Cap\']]\n\ntime_df_btc_mc.set_index("Date",inplace=True)\ntime_df_eth_mc.set_index("Date",inplace=True)\ntime_df_lte_mc.set_index("Date",inplace=True)\ntime_df_mno_mc.set_index("Date",inplace=True)\ntime_df_neo_mc.set_index("Date",inplace=True)\ntime_df_qtum_mc.set_index("Date",inplace=True)\ntime_df_rpp_mc.set_index("Date",inplace=True)\n\n'

# %%
time_df_btc_mc = btc_df.set_index('Date')['Market Cap']
time_df_eth_mc = eth_df.set_index('Date')['Market Cap']
time_df_lte_mc = lte_df.set_index('Date')['Market Cap']
time_df_mno_mc = mno_df.set_index('Date')['Market Cap']
time_df_neo_mc = neo_df.set_index('Date')['Market Cap']
time_df_qtum_mc = qtum_df.set_index('Date')['Market Cap']
time_df_rpp_mc = rpp_df.set_index('Date')['Market Cap']

# %%
time_df_btc_mc.info()
# Out:
# <class 'pandas.core.series.Series'>
# DatetimeIndex: 1655 entries, 2017-11-07 to 2013-04-28
# Series name: Market Cap
# Non-Null Count  Dtype
# --------------  -----
# 1655 non-null   int64
# dtypes: int64(1)
# memory usage: 25.9 KB

# %%
plt.figure(figsize=(20,8))
custom = sns.color_palette("husl", 7)
sns.lineplot(data=time_df_btc_mc,palette=[custom[0]],label="BTC")
sns.lineplot(data=time_df_eth_mc,palette=[custom[1]],label="ETH")
sns.lineplot(data=time_df_lte_mc,palette=[custom[2]],label="LTC")
sns.lineplot(data=time_df_mno_mc,palette=[custom[3]],label="MNO")
sns.lineplot(data=time_df_neo_mc,palette=[custom[4]],label="NEO")
sns.lineplot(data=time_df_qtum_mc,palette=[custom[5]],label="QTUM")
sns.lineplot(data=time_df_rpp_mc,palette=[custom[6]],label="RPP")
plt.xlabel("Date")
plt.ylabel("Market cap")
plt.grid(True)
plt.yscale("log")
plt.legend()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2068\359716726.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=time_df_btc_mc,palette=[custom[0]],label="BTC")
# C:\Users\HP\AppData\Local\Temp\ipykernel_2068\359716726.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=time_df_eth_mc,palette=[custom[1]],label="ETH")
# C:\Users\HP\AppData\Local\Temp\ipykernel_2068\359716726.py:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=time_df_lte_mc,palette=[custom[2]],label="LTC")
# C:\Users\HP\AppData\Local\Temp\ipykernel_2068\359716726.py:6: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=time_df_mno_mc,palette=[custom[3]],label="MNO")
# C:\Users\HP\AppData\Local\Temp\ipykernel_2068\359716726.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
# ...

# %%
help(sns.lineplot)
# Out:
# Help on function lineplot in module seaborn.relational:
#
# lineplot(data=None, *, x=None, y=None, hue=None, size=None, style=None, units=None, palette=None, hue_order=None, hue_norm=None, sizes=None, size_order=None, size_norm=None, dashes=True, markers=None, style_order=None, estimator='mean', errorbar=('ci', 95), n_boot=1000, seed=None, orient='x', sort=True, err_style='band', err_kws=None, legend='auto', ci='deprecated', ax=None, **kwargs)
#     Draw a line plot with possibility of several semantic groupings.
#
#     The relationship between `x` and `y` can be shown for different subsets
#     of the data using the `hue`, `size`, and `style` parameters. These
#     parameters control what visual semantics are used to identify the different
#     subsets. It is possible to show up to three dimensions independently by
#     using all three semantic types, but this style of plot can be hard to
#     interpret and is often ineffective. Using redundant semantics (i.e. both
# ...

# %%
"""btc_df_mc = btc_df[['Date', 'Market Cap']].rename(columns={'Market Cap': 'Market_Cap_BTC'})
eth_df_mc = eth_df[['Date', 'Market Cap']].rename(columns={'Market Cap': 'Market_Cap_ETH'})
lte_df_mc = lte_df[['Date', 'Market Cap']].rename(columns={'Market Cap': 'Market_Cap_LTC'})
neo_df_mc = neo_df[['Date', 'Market Cap']].rename(columns={'Market Cap': 'Market_Cap_NEO'})
mno_df_mc = mno_df[['Date', 'Market Cap']].rename(columns={'Market Cap': 'Market_Cap_MNO'})
qtum_df_mc = qtum_df[['Date', 'Market Cap']].rename(columns={'Market Cap': 'Market_Cap_QTUM'})
rpp_df_mc = rpp_df[['Date', 'Market Cap']].rename(columns={'Market Cap': 'Market_Cap_RPP'})"""
# Out:
# "btc_df_mc = btc_df[['Date', 'Market Cap']].rename(columns={'Market Cap': 'Market_Cap_BTC'})\neth_df_mc = eth_df[['Date', 'Market Cap']].rename(columns={'Market Cap': 'Market_Cap_ETH'})\nlte_df_mc = lte_df[['Date', 'Market Cap']].rename(columns={'Market Cap': 'Market_Cap_LTC'})\nneo_df_mc = neo_df[['Date', 'Market Cap']].rename(columns={'Market Cap': 'Market_Cap_NEO'})\nmno_df_mc = mno_df[['Date', 'Market Cap']].rename(columns={'Market Cap': 'Market_Cap_MNO'})\nqtum_df_mc = qtum_df[['Date', 'Market Cap']].rename(columns={'Market Cap': 'Market_Cap_QTUM'})\nrpp_df_mc = rpp_df[['Date', 'Market Cap']].rename(columns={'Market Cap': 'Market_Cap_RPP'})"

# %%
"""df1=pd.merge(btc_df_mc,eth_df_mc,how="inner",on="Date")
df1=pd.merge(df1,lte_df_mc,how="inner",on="Date")
df1=pd.merge(df1,mno_df_mc,how="inner",on="Date")
df1=pd.merge(df1,neo_df_mc,how="inner",on="Date")
df1=pd.merge(dfA1,qtum_df_mc,how="inner",on="Date")
df1=pd.merge(df1,rpp_df_mc,how="inner",on="Date")
"""
# Out:
# 'df1=pd.merge(btc_df_mc,eth_df_mc,how="inner",on="Date")\ndf1=pd.merge(df1,lte_df_mc,how="inner",on="Date")\ndf1=pd.merge(df1,mno_df_mc,how="inner",on="Date")\ndf1=pd.merge(df1,neo_df_mc,how="inner",on="Date")\ndf1=pd.merge(dfA1,qtum_df_mc,how="inner",on="Date")\ndf1=pd.merge(df1,rpp_df_mc,how="inner",on="Date")\n'

# %%
"""df1.columns=["Date","Open_btc","High_btc","Low_btc","Close_btc","Volume_btc","Market_Cap_btc","Open_eth","High_eth","Low_eth","Close_eth","Volume_eth","Market_Cap_eth"]"""
# Out:
# 'df1.columns=["Date","Open_btc","High_btc","Low_btc","Close_btc","Volume_btc","Market_Cap_btc","Open_eth","High_eth","Low_eth","Close_eth","Volume_eth","Market_Cap_eth"]'

# %%
"""df2=pd.merge(df1,lte_df,how="inner",on="Date")
"""
# Out:
# 'df2=pd.merge(df1,lte_df,how="inner",on="Date")\n'

# %%
plt.figure(figsize=(50,8))
sns.barplot(x=btc_df["Date"][:150],y=btc_df["Market Cap"])
plt.xticks(rotation=90)
plt.yscale("log")

# %%
help(plt.xscale)
# Out:
# Help on function xscale in module matplotlib.pyplot:
#
# xscale(value, **kwargs)
#     Set the xaxis' scale.
#
#     Parameters
#     ----------
#     value : {"linear", "log", "symlog", "logit", ...} or `.ScaleBase`
#         The axis scale type to apply.
#
#     **kwargs
#         Different keyword arguments are accepted, depending on the scale.
#         See the respective class keyword arguments:
#
#         - `matplotlib.scale.LinearScale`
#         - `matplotlib.scale.LogScale`
#         - `matplotlib.scale.SymmetricalLogScale`
#         - `matplotlib.scale.LogitScale`
#         - `matplotlib.scale.FuncScale`
#
#     Notes
#     -----
#     By default, Matplotlib supports the above-mentioned scales.
#     Additionally, custom scales may be registered using
#     `matplotlib.scale.register_scale`. These scales can then also
#     be used here.

# %%
plt.xscale("log")
sns.distplot(btc_df["Market Cap"])
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2068\936879805.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(btc_df["Market Cap"])

# %%
sns.boxplot(y=btc_df["Market Cap"])
plt.yscale("log")
plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(50,6))
plt.xticks(rotation=90)
plt.tight_layout()

sns.barplot(x=eth_df["Date"][:200],y=eth_df["Volume"])
# Out:
# <Axes: xlabel='Date', ylabel='Volume'>

# %%
sns.set_style("whitegrid")
plt.hist(btc_df["High"])
plt.yscale("log")

# %%
plt.figure(1)
plt.subplot(1,2,1)
sns.scatterplot(x="Volume",y="Market Cap",data=btc_df)
plt.subplot(1,2,2)
sns.scatterplot(x="Volume",y="Market Cap",data=eth_df)

plt.figure(2)
plt.subplot(2,2,1)
sns.scatterplot(x="Volume",y="Market Cap",data=lte_df)
plt.subplot(2,2,2)
sns.scatterplot(x="Volume",y="Market Cap",data=neo_df)
plt.figure(3)
plt.subplot(3,2,1)
sns.scatterplot(x="Volume",y="Market Cap",data=mno_df)
plt.subplot(3,2,2)
sns.scatterplot(x="Volume",y="Market Cap",data=qtum_df)

plt.figure(4)
plt.subplot(4,2,1)
sns.scatterplot(x="Volume",y="Market Cap",data=rpp_df)

plt.show()

# %%
btc_df["High"].mean()
# Out:
# 845.812664652568

# %%
btc_df["Market Cap"].mean()
# Out:
# 12724354943.202417
