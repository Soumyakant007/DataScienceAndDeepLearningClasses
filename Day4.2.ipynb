# %%
import pandas as pd

# %%
df=pd.read_csv("HR_comma_sep.csv")

# %%
df.shape
# Out:
# (14999, 10)

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'sales', 'salary'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   sales                  14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
df["satisfaction_level"]
# Out:
# 0        0.38
# 1        0.80
# 2        0.11
# 3        0.72
# 4        0.37
#          ...
# 14994    0.40
# 14995    0.37
# 14996    0.37
# 14997    0.11
# 14998    0.37
# Name: satisfaction_level, Length: 14999, dtype: float64

# %%
df2=df[["satisfaction_level","salary","sales"]]
df2.head(10)
# Out:
#    satisfaction_level  salary  sales
# 0                0.38     low  sales
# 1                0.80  medium  sales
# 2                0.11  medium  sales
# 3                0.72     low  sales
# 4                0.37     low  sales
# 5                0.41     low  sales
# 6                0.10     low  sales
# 7                0.92     low  sales
# 8                0.89     low  sales
# 9                0.42     low  sales

# %%
df2.tail(10)
# Out:
#        satisfaction_level salary      sales
# 14989                0.43    low  technical
# 14990                0.89    low    support
# 14991                0.09    low    support
# 14992                0.40    low    support
# 14993                0.76    low    support
# 14994                0.40    low    support
# 14995                0.37    low    support
# 14996                0.37    low    support
# 14997                0.11    low    support
# 14998                0.37    low    support

# %%
help(df.iloc)
# Out:
# Help on _iLocIndexer in module pandas.core.indexing object:
#
# class _iLocIndexer(_LocationIndexer)
#  |  Purely integer-location based indexing for selection by position.
#  |
#  |  ``.iloc[]`` is primarily integer position based (from ``0`` to
#  |  ``length-1`` of the axis), but may also be used with a boolean
#  |  array.
#  |
#  |  Allowed inputs are:
#  |
#  |  - An integer, e.g. ``5``.
#  |  - A list or array of integers, e.g. ``[4, 3, 0]``.
#  |  - A slice object with ints, e.g. ``1:7``.
#  |  - A boolean array.
#  |  - A ``callable`` function with one argument (the calling Series or
#  |    DataFrame) and that returns valid output for indexing (one of the above).
#  |    This is useful in method chains, when you don't have a reference to the
#  |    calling object, but would like to base your selection on some value.
#  |  - A tuple of row and column indexes. The tuple elements consist of one of the
#  |    above inputs, e.g. ``(0, 1)``.
#  |
# ...

# %%
df_copy=df.iloc[:500,[0,3,9]]

# %%
df_copy
# Out:
#      satisfaction_level  average_montly_hours  salary
# 0                  0.38                   157     low
# 1                  0.80                   262  medium
# 2                  0.11                   272  medium
# 3                  0.72                   223     low
# 4                  0.37                   159     low
# ..                  ...                   ...     ...
# 495                0.82                   263  medium
# 496                0.10                   244  medium
# 497                0.59                   263  medium
# 498                0.44                   143  medium
# 499                0.89                   181  medium
#
# [500 rows x 3 columns]

# %%
df["col1"]=1
df["impact"]=df["satisfaction_level"]*df["number_project"]

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary  col1  impact
# 0     low     1    0.76
# ...

# %%
del df["col1"]

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary  impact
# 0     low    0.76
# 1  medium    4.00
# ...

# %%
df["new_salary"]=df["salary"].str.upper()+"-New"

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary  impact  new_salary
# 0     low    0.76     LOW-New
# ...

# %%
new_df=df[(df["number_project"]>4)&(df["salary"]=="low")]
new_df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 3                    0.72             0.87               5
# 6                    0.10             0.77               6
# 7                    0.92             0.85               5
# 8                    0.89             1.00               5
# 11                   0.11             0.81               6
# ...                   ...              ...             ...
# 14987                0.90             0.70               5
# 14990                0.89             0.88               5
# 14991                0.09             0.81               6
# 14993                0.76             0.83               6
# 14997                0.11             0.96               6
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 3                       223                   5              0     1
# 6                       247                   4              0     1
# ...

# %%
new_df["number_project"].min()
# Out:
# 5

# %%
new_df["number_project"].max()
# Out:
# 7

# %%
df["sales"].unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
df_new1=df.sort_values(["impact","number_project"])
df_new1
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 622                  0.10             0.55               2
# 12622                0.10             0.55               2
# 14833                0.10             0.55               2
# 985                  0.11             0.55               2
# 5005                 0.12             0.60               2
# ...                   ...              ...             ...
# 10371                0.99             0.37               6
# 4553                 1.00             0.76               6
# 8411                 1.00             0.61               6
# 10878                1.00             0.88               6
# 13089                1.00             0.88               6
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 622                     247                   4              0     1
# 12622                   247                   4              0     1
# ...

# %%
df[df["number_project"]==7].sort_values(["satisfaction_level"])
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 1785                 0.09             0.96               7
# 610                  0.09             0.95               7
# 614                  0.09             0.90               7
# 12687                0.09             0.92               7
# 687                  0.09             0.92               7
# ...                   ...              ...             ...
# 1988                 0.51             0.60               7
# 14708                0.59             0.49               7
# 497                  0.59             0.49               7
# 12497                0.59             0.49               7
# 843                  0.66             0.47               7
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 1785                    264                   4              0     1
# 610                     256                   4              0     1
# ...

# %%
left=df
right=df.groupby(["sales"],as_index=False)["satisfaction_level"].mean()
right.columns=["sales","satisfaction_index"]

# %%
right.head(10).sort_values(["satisfaction_index"])
# Out:
#          sales  satisfaction_index
# 2   accounting            0.582151
# 3           hr            0.598809
# 9    technical            0.607897
# 7        sales            0.614447
# 0           IT            0.618142
# 8      support            0.618300
# 5    marketing            0.618601
# 6  product_mng            0.619634
# 1        RandD            0.619822
# 4   management            0.621349

# %%
df_merged=pd.merge(left,right,how="inner",on="sales")

# %%
left1=df.iloc[:1500,:4]
right1=df.iloc[:500,7:]

# %%
joined=left1.join(right1,how="left")

# %%
df_g1=df.groupby(["sales"],as_index=False)["satisfaction_level"].mean()
df_g2=df.groupby(["sales"],as_index=False)["satisfaction_level"].sum()

concated=pd.concat([df_g1,df_g2],axis=1)
concated.shape
# Out:
# (10, 4)

# %% [markdown]
# # Summary

# %% [markdown]
# Here we learned about locating rows using iloc , sorting values using sort values, joining multiple dataframes and grouping the dataframe into a new dataframe using groupby functions. According the analysis above we can have the following inferences:
# - employees in management dept are the most satisfied ones
# - The minimum number of projects done is 2, but the maximum number of projects done is 7.
# - there are employees in the office who have spent 4 years in the company but have only 2 projects, but there are people who spent 2 years but have 7 projects.
# - There are many employees who get more salary but are not satisfied, but there are employees who get less salary but are highly satisfied.
