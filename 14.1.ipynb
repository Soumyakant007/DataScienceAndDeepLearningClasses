# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
h_df=pd.read_csv("heart.csv")

# %%
h_df.describe()
# Out:
#               age         sex   pain type          BP  cholestrol         fbs  \
# count  270.000000  270.000000  270.000000  270.000000  270.000000  270.000000
# mean    54.433333    0.677778    3.174074  131.344444  249.659259    0.148148
# std      9.109067    0.468195    0.950090   17.861608   51.686237    0.355906
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  213.000000    0.000000
# 50%     55.000000    1.000000    3.000000  130.000000  245.000000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  280.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000    1.000000
#
#        resting ecg  max heart rate  exercise angina  ST depression  \
# count   270.000000      270.000000       270.000000      270.00000
# mean      1.022222      149.677778         0.329630        1.05000
# ...

# %%
h_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   age                   270 non-null    int64
#  1   sex                   270 non-null    int64
#  2   pain type             270 non-null    int64
#  3   BP                    270 non-null    int64
#  4   cholestrol            270 non-null    int64
#  5   fbs                   270 non-null    int64
#  6   resting ecg           270 non-null    int64
#  7   max heart rate        270 non-null    int64
#  8   exercise angina       270 non-null    int64
#  9   ST depression         270 non-null    float64
#  10  ST slope              270 non-null    int64
#  11  flouroscopy coloured  270 non-null    int64
#  12  thal                  270 non-null    int64
#  13  heart disease         270 non-null    int64
#  14  Unnamed: 14           0 non-null      float64
# ...

# %%
h_df.head()
# Out:
#    age  sex  pain type   BP  cholestrol  fbs  resting ecg  max heart rate  \
# 0   70    1          4  130         322    0            2             109
# 1   67    0          3  115         564    0            2             160
# 2   57    1          2  124         261    0            0             141
# 3   64    1          4  128         263    0            0             105
# 4   74    0          2  120         269    0            2             121
#
#    exercise angina  ST depression  ST slope  flouroscopy coloured  thal  \
# 0                0            2.4         2                     3     3
# 1                0            1.6         2                     0     7
# 2                0            0.3         1                     0     7
# 3                1            0.2         2                     1     7
# 4                1            0.2         1                     1     3
#
#    heart disease  Unnamed: 14
# 0              2          NaN
# ...

# %%
h_df=h_df.drop(["Unnamed: 14"],axis=1)

# %%
h_df.head()
# Out:
#    age  sex  pain type   BP  cholestrol  fbs  resting ecg  max heart rate  \
# 0   70    1          4  130         322    0            2             109
# 1   67    0          3  115         564    0            2             160
# 2   57    1          2  124         261    0            0             141
# 3   64    1          4  128         263    0            0             105
# 4   74    0          2  120         269    0            2             121
#
#    exercise angina  ST depression  ST slope  flouroscopy coloured  thal  \
# 0                0            2.4         2                     3     3
# 1                0            1.6         2                     0     7
# 2                0            0.3         1                     0     7
# 3                1            0.2         2                     1     7
# 4                1            0.2         1                     1     3
#
#    heart disease
# 0              2
# 1              1
# 2              2
# ...

# %%
X=h_df.drop("heart disease",axis=1)

# %%
y=h_df["heart disease"]

# %%
from sklearn.tree import DecisionTreeClassifier
dt_default=DecisionTreeClassifier(max_depth=3)
dt_default.fit(X,y)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
#%pip install pydotplus

# %%
#%pip install graphviz

# %%
from IPython.display import Image
from io import StringIO
from sklearn.tree import export_graphviz
import pydotplus,graphviz

# %%
features=list(X.columns)
features
# Out:
# ['age',
#  'sex',
#  'pain type',
#  'BP',
#  'cholestrol',
#  'fbs',
#  'resting ecg',
#  'max heart rate',
#  'exercise angina',
#  'ST depression',
#  'ST slope',
#  'flouroscopy coloured',
#  'thal']

# %%
h_df.shape
# Out:
# (270, 14)

# %%
h_df.isnull().sum()
# Out:
# age                     0
# sex                     0
# pain type               0
# BP                      0
# cholestrol              0
# fbs                     0
# resting ecg             0
# max heart rate          0
# exercise angina         0
# ST depression           0
# ST slope                0
# flouroscopy coloured    0
# thal                    0
# heart disease           0
# dtype: int64

# %%
help(graphviz)
# Out:
# Help on package graphviz:
#
# NAME
#     graphviz - Assemble DOT source code and render it with Graphviz.
#
# DESCRIPTION
#     Example:
#         >>> import graphviz  # doctest: +NO_EXE
#         >>> dot = graphviz.Digraph(comment='The Round Table')
#
#         >>> dot.node('A', 'King Arthur')
#         >>> dot.node('B', 'Sir Bedevere the Wise')
#         >>> dot.node('L', 'Sir Lancelot the Brave')
#
#         >>> dot.edges(['AB', 'AL'])
#
#         >>> dot.edge('B', 'L', constraint='false')
#
#         >>> print(dot)  #doctest: +NORMALIZE_WHITESPACE
#         // The Round Table
#         digraph {
#             A [label="King Arthur"]
#             B [label="Sir Bedevere the Wise"]
#             L [label="Sir Lancelot the Brave"]
#             A -> B
#             A -> L
#             B -> L [constraint=false]
#         }
#
# PACKAGE CONTENTS
#     _compat
#     _defaults
#     _tools
#     backend (package)
#     base
#     copying
#     dot
#     encoding
#     exceptions
# ...

# %%
dot_data=StringIO()
export_graphviz(dt_default,out_file=dot_data,feature_names=features,filled=True,rounded=True)

graph=pydotplus.graph_from_dot_data(dot_data.getvalue())
graph.write_pdf("dt_heartdisease.pdf")
# Out:
# True

# %%
help(StringIO)
# Out:
# Help on class StringIO in module io:
#
# class StringIO(_TextIOBase)
#  |  StringIO(initial_value='', newline='\n')
#  |
#  |  Text I/O implementation using an in-memory buffer.
#  |
#  |  The initial_value argument sets the value of object.  The newline
#  |  argument is like the one of TextIOWrapper's constructor.
#  |
#  |  Method resolution order:
#  |      StringIO
#  |      _TextIOBase
#  |      _IOBase
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __getstate__(...)
#  |      Helper for pickle.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __next__(self, /)
#  |      Implement next(self).
#  |
#  |  __setstate__(...)
#  |
#  |  close(self, /)
#  |      Close the IO object.
#  |
#  |      Attempting any further operation after the object is closed
#  |      will raise a ValueError.
#  |
#  |      This method has no effect if the file is already closed.
#  |
# ...

# %% [markdown]
# ## Summary
#
# We loaded and prepared a heart disease dataset by dropping an unnecessary column and separating features from the target variable. A DecisionTreeClassifier was trained with a maximum depth of 3. Necessary libraries (pydotplus and graphviz) were installed for visualization. The decision tree structure was exported and visualized, creating a PDF using export_graphviz and pydotplus. Basic statistics and data information were also displayed to understand the dataset.
