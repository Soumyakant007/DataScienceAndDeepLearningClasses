# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style="white")
market_df=pd.read_csv("./global_sales_data/market_fact.csv")
customer_df=pd.read_csv("./global_sales_data/cust_dimen.csv")
product_df=pd.read_csv("./global_sales_data/prod_dimen.csv")
shipping_df=pd.read_csv("./global_sales_data/shipping_dimen.csv")
orders_df=pd.read_csv("./global_sales_data/orders_dimen.csv")

# %%
market_df.shape
# Out:
# (8399, 10)

# %%
customer_df.shape
# Out:
# (1832, 5)

# %%
product_df.shape
# Out:
# (17, 3)

# %%
shipping_df.shape
# Out:
# (7701, 4)

# %%
orders_df.shape
# Out:
# (5506, 4)

# %%
market_df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
product_df.head()
# Out:
#   Product_Category            Product_Sub_Category Prod_id
# 0  OFFICE SUPPLIES          STORAGE & ORGANIZATION  Prod_1
# 1  OFFICE SUPPLIES                      APPLIANCES  Prod_2
# 2  OFFICE SUPPLIES  BINDERS AND BINDER ACCESSORIES  Prod_3
# 3       TECHNOLOGY    TELEPHONES AND COMMUNICATION  Prod_4
# 4        FURNITURE              OFFICE FURNISHINGS  Prod_5

# %% [markdown]
# Merge dataframes

# %%
df=pd.merge(market_df,product_df,how="inner",on="Prod_id")
df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id   Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818  136.81      0.01              23
# 1  Ord_2978  Prod_16  SHP_4112  Cust_1088  305.05      0.04              27
# 2  Ord_5484  Prod_16  SHP_7663  Cust_1820  322.82      0.05              35
# 3  Ord_3730  Prod_16  SHP_5175  Cust_1314  459.08      0.04              34
# 4  Ord_4143  Prod_16  SHP_5771  Cust_1417  207.21      0.06              24
#
#    Profit  Shipping_Cost  Product_Base_Margin Product_Category  \
# 0  -30.51           3.60                 0.56  OFFICE SUPPLIES
# 1   23.12           3.37                 0.57  OFFICE SUPPLIES
# 2  -17.58           3.98                 0.56  OFFICE SUPPLIES
# 3   61.57           3.14                 0.60  OFFICE SUPPLIES
# 4  -78.64           6.14                 0.59  OFFICE SUPPLIES
#
#             Product_Sub_Category
# 0  SCISSORS, RULERS AND TRIMMERS
# 1  SCISSORS, RULERS AND TRIMMERS
# ...

# %%
sns.boxplot(x="Product_Category",y="Sales",data=df)
plt.yscale("log")
plt.show()

# %%
sns.boxplot(x="Product_Category",y="Profit",data=df)

plt.show()

# %%
df=df[(df["Profit"]<1000) & (df["Profit"]>-1000)]
sns.boxplot(x="Product_Category",y="Profit",data=df)
plt.show()

# %%
plt.figure(figsize=(11,5))

plt.subplot(1,2,1)
sns.boxplot(x="Product_Category",y="Sales",data=df)
plt.title("Sales")
plt.yscale("log")
plt.subplot(1,2,2)
sns.boxplot(x="Product_Category",y="Profit",data=df)
plt.title("Profit")
plt.show()

# %% [markdown]
# # Day4

# %% [markdown]
# ## Bar Chart
#
# The number of values of the specified values

# %% [markdown]
# ## Pie chart
#
# the percentage of value of a specific variable

# %% [markdown]
# ## Box plot
#
# - mean,
# - median,
# - min,
# - max,
# - range,
# - quartile

# %% [markdown]
# ## Histogram
#
#    - Variance,
#    - Standard Deviation,
#    - COefficient of deviation,
#    - Skewness,
#    - Kurtosis

# %% [markdown]
# ## Scatter chart
#
# two numerical atributes
#
# ## Bar Chart
#
# average value of numerical attribute across different classes if categorical attribute
#
# ## Stacked Bar
#
# compares the percentage that each category from one attriubute contributes to total across categories of the second variable

# %% [markdown]
# # Data manipulation and Engineering
#
#     -read csv file
#     -Exploring length,breadth,shape,head,tail etc
#
#
# #### CRUD
#
# - CR=new cols/rows
# - U=update cols/filter
# - D=delete cols
#
#
# #### Data Engineering:
#
# - Transform Data
# - String Manipulation
# - Data Rollup(Groupby)
# - Merge, Join, Pivot, concat

# %% [markdown]
# ### Measure of central tendency
#
# mean, median, mode
#
# ### Measure of variability
#
# - Range,
# - variance,
# - standard deviation

# %% [markdown]
# # Central Limit Theorem
#
# the CLT states that given a large population with a finite variance, the mean of all samples from the same population will be approximately equal to the mean of the sample

# %% [markdown]
# # Hypothesis testing
#
# assumption about a population
# - Set up Hypothesis(NULL and Alternate)
# - Set the criteria for decision
# - Compute the random chance of probability
# - Take a decision

# %% [markdown]
# # Data Cleansing
# - Data Deduplication
# - Data analysis
# - Data Standardization
# - Data Normalization
# - Quality check

# %%
customer_df.head()
# Out:
#         Customer_Name Province   Region Customer_Segment Cust_id
# 0  MUHAMMED MACINTYRE  NUNAVUT  NUNAVUT   SMALL BUSINESS  Cust_1
# 1        BARRY FRENCH  NUNAVUT  NUNAVUT         CONSUMER  Cust_2
# 2       CLAY ROZENDAL  NUNAVUT  NUNAVUT        CORPORATE  Cust_3
# 3      CARLOS SOLTERO  NUNAVUT  NUNAVUT         CONSUMER  Cust_4
# 4        CARL JACKSON  NUNAVUT  NUNAVUT        CORPORATE  Cust_5

# %%
df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id   Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818  136.81      0.01              23
# 1  Ord_2978  Prod_16  SHP_4112  Cust_1088  305.05      0.04              27
# 2  Ord_5484  Prod_16  SHP_7663  Cust_1820  322.82      0.05              35
# 3  Ord_3730  Prod_16  SHP_5175  Cust_1314  459.08      0.04              34
# 4  Ord_4143  Prod_16  SHP_5771  Cust_1417  207.21      0.06              24
#
#    Profit  Shipping_Cost  Product_Base_Margin Product_Category  \
# 0  -30.51           3.60                 0.56  OFFICE SUPPLIES
# 1   23.12           3.37                 0.57  OFFICE SUPPLIES
# 2  -17.58           3.98                 0.56  OFFICE SUPPLIES
# 3   61.57           3.14                 0.60  OFFICE SUPPLIES
# 4  -78.64           6.14                 0.59  OFFICE SUPPLIES
#
#             Product_Sub_Category
# 0  SCISSORS, RULERS AND TRIMMERS
# 1  SCISSORS, RULERS AND TRIMMERS
# ...

# %%
df=pd.merge(df,customer_df, how="inner",on="Cust_id")

# %%
df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 3  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.02      0.03              23
# 4  Ord_2978  Prod_16  SHP_4112  Cust_1088   305.05      0.04              27
#
#    Profit  Shipping_Cost  Product_Base_Margin Product_Category  \
# 0  -30.51           3.60                 0.56  OFFICE SUPPLIES
# 1    4.56           0.93                 0.54  OFFICE SUPPLIES
# 2  729.34          14.30                 0.37  OFFICE SUPPLIES
# 3  -47.64           6.15                 0.37  OFFICE SUPPLIES
# 4   23.12           3.37                 0.57  OFFICE SUPPLIES
#
#             Product_Sub_Category  Customer_Name Province   Region  \
# ...

# %%
df.describe()
# Out:
# count          7503
# unique            4
# top       CORPORATE
# freq           2740
# Name: Customer_Segment, dtype: object

# %%
df=df[(df.Customer_Segment<100 & df.Customer_Segment)]

# %%
sns.boxplot(x="Customer_Segment",y="Profit",data=df)
# Out:
# <Axes: xlabel='Customer_Segment', ylabel='Profit'>

# %%
plt.figure(num=None,figsize=(12,8),dpi=120, facecolor="c", edgecolor="b")

sns.boxplot(x="Customer_Segment", y="Profit", hue="Product_Category", data=df)
# Out:
# <Axes: xlabel='Customer_Segment', ylabel='Profit'>

# %%
sns.boxplot(x=df["Product_Category"],y=100*(df["Shipping_Cost"]/df["Sales"]))
plt.yscale("log")
plt.ylabel("100*(Shipping_Cost/Sales)")
plt.show()

# %% [markdown]
# # Bar Plot

# %%
sns.barplot(x="Product_Category",y="Sales", data=df)
# Out:
# <Axes: xlabel='Product_Category', ylabel='Sales'>

# %%
plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
sns.barplot(x="Product_Category",y="Sales",data=df,estimator=np.mean)


plt.subplot(1,2,2)
sns.barplot(x="Product_Category",y="Sales",data=df,estimator=np.median)
# Out:
# <Axes: xlabel='Product_Category', ylabel='Sales'>

# %%
plt.figure(num=None,figsize=(12,8),dpi=120, facecolor="c", edgecolor="b")
sns.barplot(x="Customer_Segment",y="Profit",hue="Product_Category",data=df,estimator=np.median)
# Out:
# <Axes: xlabel='Customer_Segment', ylabel='Profit'>

# %%
plt.figure(figsize=(12,8))
sns.barplot(x="Profit",y="Product_Sub_Category",data=df,estimator=np.median)
# Out:
# <Axes: xlabel='Profit', ylabel='Product_Sub_Category'>

# %%
plt.figure(figsize=(10,8))
sns.countplot(y="Product_Sub_Category",data=df)
# Out:
# <Axes: xlabel='count', ylabel='Product_Sub_Category'>
